# %% [markdown]
# Для Task 0.3 Used - https://www.geeksforgeeks.org/python/higher-order-functions-in-python/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
