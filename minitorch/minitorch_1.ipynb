# %% [markdown]
# Использовала гпт для объяснения в классе ScalarFunction функцию apply и в общем класс ScalarFunction.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
if __name__ == "__main__":
    PTS = 50
    HIDDEN = 8
    RATE = 0.1
    data = minitorch.datasets["Simple"](PTS)
    ScalarTrain(HIDDEN).train(data, RATE)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
PTS = 50
data = minitorch.datasets["Xor"](PTS)

HIDDEN = 10
RATE = 0.5
ScalarTrain(HIDDEN).train(data, RATE)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
PTS = 50
data = minitorch.datasets["Diag"](PTS)

HIDDEN = 4
RATE = 0.5
ScalarTrain(HIDDEN).train(data, RATE)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
PTS = 50
data = minitorch.datasets["Split"](PTS)

HIDDEN = 4
RATE = 0.5
ScalarTrain(HIDDEN).train(data, RATE)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Подписи к датасетам в datasets.py написал GPT (я всё, что там происходит понимаю, просто нет времени писать описания)
